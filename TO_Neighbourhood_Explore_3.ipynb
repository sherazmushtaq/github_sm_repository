# %%
from bs4 import BeautifulSoup
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %% [markdown]
# * Define a variable for URL
# * Print URL value and make sure URL is valid

# %%
# Define a variable for URL 
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
results = requests.get(url)
print(results)
# Out:
# <Response [200]>

# %% [markdown]
#  * Get the HTML page contents
#  * Convert the page to BeautifulSoup for parsing

# %%
 #get the HTML page contents
ca_postal_code_page = results.text

# Covert the page to SOUP
html_soup_page = BeautifulSoup(ca_postal_code_page, 'lxml')

# %% [markdown]
# * Get the HTML Postal Codes table data
# * Assign table rows to a separate variable

# %%
# Get the HTML Postal Codes table data
table_detail = html_soup_page.find('table', class_='wikitable sortable')
table_rows = table_detail.find_all('tr')

# %% [markdown]
# * Loop through each row and skip that row where Borough is Not assigned
# * Also update "Not assigned" Neighbourhood value to Borough

# %%
a='Not assigned'
res = []
tab_row=[]
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    
    if row:
       if row[1] != a:
          if row[2] == a:
              row[2] = row[1] 
          res.append(row)
      
df = pd.DataFrame(res, columns=['PostalCode','Borough','Neighbourhood'])
df.shape
# Out:
# (211, 3)

# %% [markdown]
# * Combine the rows by Postal Code and display all Neighbourhoods under that postal code in one row

# %%
# Combine rows by postal code so we combine 
page_header = html_soup_page.title.text

df_combine = df.groupby(['PostalCode','Borough'])['Neighbourhood'].agg(lambda col: ', '.join(col.astype('str'))).reset_index()

# %% [markdown]
# * Get Coordinates data from CSV file and join the two dataframes on Postal Code
# * Note: I was not able to get the geographical coordinates of the neighborhoods using the Geocoder package therefore I had to use CSV file.

# %%
file_url = 'http://cocl.us/Geospatial_data'
df_cords = pd.read_csv(file_url, skiprows=[0], header = None)

df_cords.columns=['Code','Latitude','Longitude']

pd.merge(df_combine, df_cords, left_on="PostalCode", right_on="Code").drop('Code', axis=1)
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# 30         M3K        North York
# 31         M3L        North York
# 32         M3M        North York
# 33         M3N        North York
# 34         M4A        North York
# 35         M4B         East York
# 36         M4C         East York
# 37         M4E      East Toronto
# 38         M4G         East York
# 39         M4H         East York
# 40         M4J         East York
# 41         M4K      East Toronto
# 42         M4L      East Toronto
# 43         M4M      East Toronto
# 44         M4N   Central Toronto
# 45         M4P   Central Toronto
# 46         M4R   Central Toronto
# 47         M4S   Central Toronto
# 48         M4T   Central Toronto
# 49         M4V   Central Toronto
# 50         M4W  Downtown Toronto
# 51         M4X  Downtown Toronto
# 52         M4Y  Downtown Toronto
# 53         M5A  Downtown Toronto
# 54         M5B  Downtown Toronto
# 55         M5C  Downtown Toronto
# 56         M5E  Downtown Toronto
# 57         M5G  Downtown Toronto
# 58         M5H  Downtown Toronto
# 59         M5J  Downtown Toronto
# 60         M5K  Downtown Toronto
# 61         M5L  Downtown Toronto
# 62         M5M        North York
# 63         M5N   Central Toronto
# 64         M5P   Central Toronto
# 65         M5R   Central Toronto
# 66         M5S  Downtown Toronto
# 67         M5T  Downtown Toronto
# 68         M5V  Downtown Toronto
# 69         M5W  Downtown Toronto
# 70         M5X  Downtown Toronto
# 71         M6A        North York
# 72         M6B        North York
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1               Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6          East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 7                      Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 8      Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 9                          Birch Cliff, Cliffside West  43.692657 -79.264848
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 11                                   Maryvale, Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                            Silver Hills, York Mills  43.757490 -79.374714
# 21                             Newtonbrook, Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                     Northwood Park, York University  43.767980 -79.487262
# 30                         CFB Toronto, Downsview East  43.737473 -79.464763
# 31                                      Downsview West  43.739015 -79.506944
# 32                                   Downsview Central  43.728496 -79.495697
# 33                                 Downsview Northwest  43.761631 -79.520999
# 34                                    Victoria Village  43.725882 -79.315572
# 35                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 36                                    Woodbine Heights  43.695344 -79.318389
# 37                                         The Beaches  43.676357 -79.293031
# 38                                             Leaside  43.709060 -79.363452
# 39                                    Thorncliffe Park  43.705369 -79.349372
# 40                                        East Toronto  43.685347 -79.338106
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# 42                      The Beaches West, India Bazaar  43.668999 -79.315572
# 43                                     Studio District  43.659526 -79.340923
# 44                                       Lawrence Park  43.728020 -79.388790
# 45                                    Davisville North  43.712751 -79.390197
# 46                                  North Toronto West  43.715383 -79.405678
# 47                                          Davisville  43.704324 -79.388790
# 48                         Moore Park, Summerhill East  43.689574 -79.383160
# 49   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 50                                            Rosedale  43.679563 -79.377529
# 51                         Cabbagetown, St. James Town  43.667967 -79.367675
# 52                                Church and Wellesley  43.665860 -79.383160
# 53                           Harbourfront, Regent Park  43.654260 -79.360636
# 54                            Ryerson, Garden District  43.657162 -79.378937
# 55                                      St. James Town  43.651494 -79.375418
# 56                                         Berczy Park  43.644771 -79.373306
# 57                                  Central Bay Street  43.657952 -79.387383
# 58                            Adelaide, King, Richmond  43.650571 -79.384568
# 59   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 60            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 61                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 62                   Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 63                                            Roselawn  43.711695 -79.416936
# 64                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 65                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 66                      Harbord, University of Toronto  43.662696 -79.400049
# 67           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 68   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 69                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 70              First Canadian Place, Underground city  43.648429 -79.382280
# 71                    Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 72                                           Glencairn  43.709577 -79.445073
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 77                            Little Portugal, Trinity  43.647927 -79.419750
# 78        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 79                  Downsview, North Park, Upwood Park  43.713756 -79.490074
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 81                       The Junction North, Runnymede  43.673185 -79.487262
# 82                       High Park, The Junction South  43.661608 -79.464763
# 83                              Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                  Runnymede, Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89                              Alderwood, Long Branch  43.602414 -79.543484
# 90       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 91   Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 92   Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                    Emery, Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054

# %% [markdown]
# * Get teh coordinates of Toronto city

# %%
neighborhoods=pd.merge(df_combine, df_cords, left_on="PostalCode", right_on="Code").drop('Code', axis=1)
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.

# %% [markdown]
# * Loop through Toronto city Borough Coordinates and display city map

# %%
# create map of Toronto using latitude and longitude values
map_to = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_to)  
    
map_to
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * We will do the clustring of all those Boroughs where Toronto is part of Borough name

# %%
to_downtown_neighborhoods = neighborhoods[neighborhoods['Borough'].str.contains('Toronto')].reset_index(drop=True)
to_downtown_neighborhoods.head()
# Out:
#   PostalCode          Borough                   Neighbourhood   Latitude  \
# 0        M4E     East Toronto                     The Beaches  43.676357
# 1        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2        M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3        M4M     East Toronto                 Studio District  43.659526
# 4        M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %% [markdown]
# * Disply these Boroughs as cluster on Map

# %%
# Disply these Boroughs as cluster on Map 
map_to = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(to_downtown_neighborhoods['Latitude'], to_downtown_neighborhoods['Longitude'], to_downtown_neighborhoods['Borough'], to_downtown_neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_to)  
    
map_to
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * Use Credentials to access Foursquare

# %%
CLIENT_ID = 'TKVOOCUPD0AUTPWYELLMG1VN5TJY4K0ASQBYR3QRTYGEKACE' # your Foursquare ID
CLIENT_SECRET = 'YIMMLNYUKL5WOK2EGUOOBCA3ZPXJZDYTVCWPVMYCMJBFOZS0' # your Foursquare Secret
VERSION = '20190809' # Foursquare API version

# %% [markdown]
# * Explore the Borough in location 1

# %%
to_downtown_neighborhoods.loc[1, 'Neighbourhood']
# Out:
# 'The Danforth West, Riverdale'

# %% [markdown]
# * Get the Latitude and Longitude coordinates of that location

# %%
neighborhood_latitude = to_downtown_neighborhoods.loc[1, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = to_downtown_neighborhoods.loc[1, 'Longitude'] # neighborhood longitude value

neighborhood_name = east_to_neighborhoods.loc[1, 'Neighbourhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Highland Creek, Rouge Hill, Port Union are 43.6795571, -79.352188.

# %% [markdown]
# * Limit the number of venus within the radius of 500

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=TKVOOCUPD0AUTPWYELLMG1VN5TJY4K0ASQBYR3QRTYGEKACE&client_secret=YIMMLNYUKL5WOK2EGUOOBCA3ZPXJZDYTVCWPVMYCMJBFOZS0&v=20190809&ll=43.6795571,-79.352188&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d4dc8ccd69ed0002d0a2eac'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Greektown',
#   'headerFullLocation': 'Greektown, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 41,
#   'suggestedBounds': {'ne': {'lat': 43.6840571045, 'lng': -79.34597738331301},
#    'sw': {'lat': 43.675057095499994, 'lng': -79.35839861668698}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bce4183ef10952197da8386',
#        'name': 'Pantheon',
#        'location': {'address': '407 Danforth Ave.',
#         'crossStreet': 'at Chester Ave.',
#         'lat': 43.67762124481265,
#         'lng': -79.35143390043564,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67762124481265,
#           'lng': -79.35143390043564}],
#         'distance': 223,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['407 Danforth Ave. (at Chester Ave.)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bce4183ef10952197da8386-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc72844d22dafda2fcf75e6',
#        'name': 'Dolce Gelato',
#        'location': {'address': '414 Danforth Ave',
#         'lat': 43.677772998450614,
#         'lng': -79.35118737317053,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677772998450614,
#           'lng': -79.35118737317053}],
#         'distance': 214,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['414 Danforth Ave',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc72844d22dafda2fcf75e6-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5102df8df13673cd7084ac39',
#        'name': 'MenEssentials',
#        'location': {'address': '412 Danforth Ave.',
#         'crossStreet': 'Near Danforth and Chester',
#         'lat': 43.677820068604575,
#         'lng': -79.35126543045044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677820068604575,
#           'lng': -79.35126543045044}],
#         'distance': 207,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['412 Danforth Ave. (Near Danforth and Chester)',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50073247'}},
#       'referralId': 'e-0-5102df8df13673cd7084ac39-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3dbb5e45dd68e3273e03b7',
#        'name': 'Cafe Fiorentina',
#        'location': {'address': '463 Danforth Ave',
#         'crossStreet': 'Logan Ave',
#         'lat': 43.677743,
#         'lng': -79.350115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677743,
#           'lng': -79.350115}],
#         'distance': 261,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['463 Danforth Ave (Logan Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e3dbb5e45dd68e3273e03b7-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57799e91498e189817c91ead',
#        'name': 'La Diperie',
#        'location': {'address': '372 Danforth Ave',
#         'lat': 43.67753,
#         'lng': -79.352295,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67753,
#           'lng': -79.352295}],
#         'distance': 225,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['372 Danforth Ave',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57799e91498e189817c91ead-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aeb268bf964a52006bf21e3',
#        'name': 'Messini Authentic Gyros',
#        'location': {'address': '445 Danforth Ave',
#         'crossStreet': 'at Logan Ave',
#         'lat': 43.677827494513096,
#         'lng': -79.35056873157725,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677827494513096,
#           'lng': -79.35056873157725}],
#         'distance': 232,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['445 Danforth Ave (at Logan Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aeb268bf964a52006bf21e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '541ed0a3498e7ff705517bcd',
#        'name': 'Louis Cifer Brew Works',
#        'location': {'address': '417 Danforth Ave',
#         'crossStreet': 'at Chester Ave',
#         'lat': 43.677662745359996,
#         'lng': -79.3513125762371,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677662745359996,
#           'lng': -79.3513125762371}],
#         'distance': 222,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['417 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '95245706'}},
#       'referralId': 'e-0-541ed0a3498e7ff705517bcd-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b677c35f964a520c7512be3',
#        'name': 'Moksha Yoga Danforth',
#        'location': {'address': '372 Danforth Ave',
#         'crossStreet': 'at Chester Ave',
#         'lat': 43.67762174479883,
#         'lng': -79.3521159367257,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67762174479883,
#           'lng': -79.3521159367257}],
#         'distance': 215,
#         'postalCode': 'M4K 1N8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['372 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1N8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b677c35f964a520c7512be3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afdfadff964a520a52c22e3',
#        'name': 'Mezes',
#        'location': {'address': '456 Danforth Ave',
#         'crossStreet': 'at Logan Ave.',
#         'lat': 43.6779622615441,
#         'lng': -79.35019606997218,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6779622615441,
#           'lng': -79.35019606997218}],
#         'distance': 239,
#         'postalCode': 'M4K 1P4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['456 Danforth Ave (at Logan Ave.)',
#          'Toronto ON M4K 1P4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4afdfadff964a520a52c22e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae24088f964a5206b8c21e3',
#        'name': 'The Auld Spot Pub',
#        'location': {'address': '347 Danforth Ave',
#         'crossStreet': 'at Hampton Ave',
#         'lat': 43.67733505610778,
#         'lng': -79.35312964755529,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67733505610778,
#           'lng': -79.35312964755529}],
#         'distance': 258,
#         'postalCode': 'M4K 1N7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['347 Danforth Ave (at Hampton Ave)',
#          'Toronto ON M4K 1N7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae24088f964a5206b8c21e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af4e0d0f964a5202ff721e3',
#        'name': '7 Numbers',
#        'location': {'address': '307 Danforth Ave.',
#         'crossStreet': 'at Bowden St',
#         'lat': 43.677061774959824,
#         'lng': -79.35393428891682,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677061774959824,
#           'lng': -79.35393428891682}],
#         'distance': 311,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['307 Danforth Ave. (at Bowden St)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af4e0d0f964a5202ff721e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb2727135f0c9b66749bb83',
#        'name': 'Valley Farm Produce',
#        'location': {'address': '466 Danforth Ave',
#         'crossStreet': 'at Logan Ave',
#         'lat': 43.677999294687275,
#         'lng': -79.3499690927287,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677999294687275,
#           'lng': -79.3499690927287}],
#         'distance': 248,
#         'postalCode': 'M4K 1P4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['466 Danforth Ave (at Logan Ave)',
#          'Toronto ON M4K 1P4',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b1c',
#          'name': 'Fruit & Vegetable Store',
#          'pluralName': 'Fruit & Vegetable Stores',
#          'shortName': 'Fruit & Vegetable Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb2727135f0c9b66749bb83-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b64ce4af964a52084d12ae3',
#        'name': "Christina's On The Danforth",
#        'location': {'address': '492 Danforth Avenue',
#         'crossStreet': '& Logan Av',
#         'lat': 43.678239784878826,
#         'lng': -79.34918494943804,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678239784878826,
#           'lng': -79.34918494943804}],
#         'distance': 282,
#         'postalCode': 'M4K 1P6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['492 Danforth Avenue (& Logan Av)',
#          'Toronto ON M4K 1P6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b64ce4af964a52084d12ae3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b466804f964a520ed1f26e3',
#        'name': 'Caffé Demetre',
#        'location': {'address': '400 Danforth Ave',
#         'crossStreet': 'Chester & Arundel',
#         'lat': 43.67768266377745,
#         'lng': -79.35160842812537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67768266377745,
#           'lng': -79.35160842812537}],
#         'distance': 213,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['400 Danforth Ave (Chester & Arundel)',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b466804f964a520ed1f26e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae29e2af964a520338f21e3',
#        'name': 'Alexandros',
#        'location': {'address': '484 Danforth Ave',
#         'crossStreet': 'Logan Ave',
#         'lat': 43.67830448799868,
#         'lng': -79.34948556208978,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67830448799868,
#           'lng': -79.34948556208978}],
#         'distance': 258,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['484 Danforth Ave (Logan Ave)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae29e2af964a520338f21e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec857560e6158baffa4fc3c',
#        'name': 'Pizzeria Libretto',
#        'location': {'address': '550 Danforth Ave',
#         'crossStreet': 'at Carlaw Ave',
#         'lat': 43.678488633358,
#         'lng': -79.34757579277853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678488633358,
#           'lng': -79.34757579277853}],
#         'distance': 389,
#         'postalCode': 'M4K 1P7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['550 Danforth Ave (at Carlaw Ave)',
#          'Toronto ON M4K 1P7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec857560e6158baffa4fc3c-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b26a6a9f964a520ff7e24e3',
#        'name': 'Re: Reading',
#        'location': {'address': '548 Danforth Ave.',
#         'crossStreet': 'Carlaw',
#         'lat': 43.678506570428084,
#         'lng': -79.34767758382526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678506570428084,
#           'lng': -79.34767758382526}],
#         'distance': 381,
#         'postalCode': 'M4K 1P8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['548 Danforth Ave. (Carlaw)',
#          'Toronto ON M4K 1P8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b26a6a9f964a520ff7e24e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5916090a69e77b035ceb1a86',
#        'name': 'Rikkochez',
#        'location': {'address': '341 Danforth Ave',
#         'crossStreet': 'across from Carrot Common — TTC: Chester',
#         'lat': 43.677267,
#         'lng': -79.353274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677267,
#           'lng': -79.353274}],
#         'distance': 269,
#         'postalCode': 'M4K 1N7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['341 Danforth Ave (across from Carrot Common — TTC: Chester)',
#          'Toronto ON M4K 1N7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '419057819'}},
#       'referralId': 'e-0-5916090a69e77b035ceb1a86-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd1db4e046076b0f1a57271',
#        'name': 'The Big Carrot Organic Juice Bar',
#        'location': {'address': '348 Danforth Ave',
#         'crossStreet': 'Hampton Avenue',
#         'lat': 43.677438,
#         'lng': -79.352683,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677438,
#           'lng': -79.352683}],
#         'distance': 239,
#         'postalCode': 'M4K 1N8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['348 Danforth Ave (Hampton Avenue)',
#          'Toronto ON M4K 1N8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd1db4e046076b0f1a57271-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c508ae15ee81b8d9ee3c5fe',
#        'name': 'Tsaa Tea Shop',
#        'location': {'address': 'Danforth',
#         'crossStreet': 'Chester',
#         'lat': 43.67776898684133,
#         'lng': -79.35130446081268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67776898684133,
#           'lng': -79.35130446081268}],
#         'distance': 211,
#         'postalCode': 'M4k 3e3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Danforth (Chester)',
#          'Toronto ON M4k 3e3',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c508ae15ee81b8d9ee3c5fe-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ff964a52042f720e3',
#        'name': 'Astoria Shish Kebob House',
#        'location': {'address': '390 Danforth Ave',
#         'crossStreet': 'at Chester Ave',
#         'lat': 43.67768890877185,
#         'lng': -79.35189216872803,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67768890877185,
#           'lng': -79.35189216872803}],
#         'distance': 209,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['390 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05ff964a52042f720e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe3c929474c9b6d54cd9b6',
#        'name': "Athen's Pastries",
#        'location': {'address': '509 Danforth Ave.',
#         'crossStreet': 'at Fenwick Ave.',
#         'lat': 43.67816589533113,
#         'lng': -79.34892679522846,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67816589533113,
#           'lng': -79.34892679522846}],
#         'distance': 304,
#         'cc': 'CA',
#         'neighborhood': 'Riverdale',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['509 Danforth Ave. (at Fenwick Ave.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe3c929474c9b6d54cd9b6-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548b33b0498e29d276209eca',
#        'name': 'IQ Living',
#        'location': {'address': '542 Danforth Ave',
#         'crossStreet': 'at Carlaw Ave',
#         'lat': 43.678477,
#         'lng': -79.347811,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678477,
#           'lng': -79.347811}],
#         'distance': 372,
#         'postalCode': 'M4K 1P8',
#         'cc': 'CA',
#         'neighborhood': 'Greektown',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['542 Danforth Ave (at Carlaw Ave)',
#          'Toronto ON M4K 1P8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548b33b0498e29d276209eca-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1d5337eac020a1cb1048c2',
#        'name': 'Sher-E-Punjab',
#        'location': {'address': '351 Danforth Ave',
#         'crossStreet': 'at Jackman Ave',
#         'lat': 43.67730788939673,
#         'lng': -79.35306551709385,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67730788939673,
#           'lng': -79.35306551709385}],
#         'distance': 260,
#         'postalCode': 'M4K 1N7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['351 Danforth Ave (at Jackman Ave)',
#          'Toronto ON M4K 1N7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1d5337eac020a1cb1048c2-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae4bc2ff964a520909d21e3',
#        'name': 'Urban Nails',
#        'location': {'address': '179 Danforth Ave',
#         'lat': 43.676667789021906,
#         'lng': -79.35660190332753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.676667789021906,
#           'lng': -79.35660190332753}],
#         'distance': 479,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['179 Danforth Ave', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae4bc2ff964a520909d21e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be9a0a46295c9b697738508',
#        'name': 'Don Valley Trail',
#        'location': {'lat': 43.67633091997674,
#         'lng': -79.35392333297455,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67633091997674,
#           'lng': -79.35392333297455}],
#         'distance': 385,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be9a0a46295c9b697738508-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51520f12e4b0506736121eaf',
#        'name': 'Bulk Barn',
#        'location': {'address': '213 Danforth Ave',
#         'lat': 43.67678989740336,
#         'lng': -79.35586511284247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67678989740336,
#           'lng': -79.35586511284247}],
#         'distance': 427,
#         'postalCode': 'M4K 1N2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['213 Danforth Ave',
#          'Toronto ON M4K 1N2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51520f12e4b0506736121eaf-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc10b17461576b00f537b32',
#        'name': 'Detroit Eatery',
#        'location': {'address': '389 Danforth Ave.',
#         'crossStreet': 'Chester',
#         'lat': 43.67759437002395,
#         'lng': -79.35176144372598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67759437002395,
#           'lng': -79.35176144372598}],
#         'distance': 221,
#         'postalCode': 'M4K 1P1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['389 Danforth Ave. (Chester)',
#          'Toronto ON M4K 1P1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc10b17461576b00f537b32-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fc0110498ecbc14aa76933',
#        'name': 'Marvel Coffee Co.',
#        'location': {'address': '792 Carlaw Ave.',
#         'crossStreet': 'Danforth',
#         'lat': 43.678629530863844,
#         'lng': -79.34746013725268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678629530863844,
#           'lng': -79.34746013725268}],
#         'distance': 394,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['792 Carlaw Ave. (Danforth)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55fc0110498ecbc14aa76933-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b396a9ef964a520495c25e3',
#        'name': 'Pan on the Danforth',
#        'location': {'address': '516 Danforth Ave.',
#         'lat': 43.678263168189865,
#         'lng': -79.34864777195595,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678263168189865,
#           'lng': -79.34864777195595}],
#         'distance': 319,
#         'postalCode': 'M4K 1P6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['516 Danforth Ave.',
#          'Toronto ON M4K 1P6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b396a9ef964a520495c25e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5269ba3c498ea63de3eb987b',
#        'name': "Simone's Caribbean Restaurant",
#        'location': {'address': '596 Danforth Avenue',
#         'crossStreet': 'Pape And Danforth',
#         'lat': 43.67865547474292,
#         'lng': -79.34658157954753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67865547474292,
#           'lng': -79.34658157954753}],
#         'distance': 462,
#         'postalCode': 'M4K 1R1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['596 Danforth Avenue (Pape And Danforth)',
#          'Toronto ON M4K 1R1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5269ba3c498ea63de3eb987b-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af5de4ff964a5200cfe21e3',
#        'name': 'Second Cup',
#        'location': {'address': '355 Danforth Avenue',
#         'crossStreet': 'at Hampton Ave',
#         'lat': 43.67718757165012,
#         'lng': -79.3529747898985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67718757165012,
#           'lng': -79.3529747898985}],
#         'distance': 271,
#         'postalCode': 'M4K 1N7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['355 Danforth Avenue (at Hampton Ave)',
#          'Toronto ON M4K 1N7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af5de4ff964a5200cfe21e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aec8fe3f964a520bcc821e3',
#        'name': 'Dough Bakeshop',
#        'location': {'address': '173 Danforth Ave.',
#         'crossStreet': 'Broadview',
#         'lat': 43.67664308520287,
#         'lng': -79.35684634585105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67664308520287,
#           'lng': -79.35684634585105}],
#         'distance': 495,
#         'postalCode': 'M4K 1N2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['173 Danforth Ave. (Broadview)',
#          'Toronto ON M4K 1N2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aec8fe3f964a520bcc821e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afc9333f964a5200c2422e3',
#        'name': 'Kalyvia',
#        'location': {'address': '420 Danforth Ave.',
#         'lat': 43.67778842418106,
#         'lng': -79.35112697032189,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67778842418106,
#           'lng': -79.35112697032189}],
#         'distance': 214,
#         'postalCode': 'M4K 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['420 Danforth Ave.',
#          'Toronto ON M4K 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4afc9333f964a5200c2422e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aeb2666f964a52005bf21e3',
#        'name': 'Brass Taps Pizza Pub',
#        'location': {'address': '493 Danforth Ave',
#         'crossStreet': 'at Logan Ave',
#         'lat': 43.67792441318533,
#         'lng': -79.34930702872876,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67792441318533,
#           'lng': -79.34930702872876}],
#         'distance': 294,
#         'postalCode': 'M4K 1P5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['493 Danforth Ave (at Logan Ave)',
#          'Toronto ON M4K 1P5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aeb2666f964a52005bf21e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8d7b70f964a52063fe32e3',
#        'name': 'Cafe Frappe',
#        'location': {'address': '521 Danforth Ave.',
#         'crossStreet': 'Fenwick Avenue',
#         'lat': 43.67812618087551,
#         'lng': -79.34843379217203,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67812618087551,
#           'lng': -79.34843379217203}],
#         'distance': 341,
#         'postalCode': 'M4K 1P5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['521 Danforth Ave. (Fenwick Avenue)',
#          'Toronto ON M4K 1P5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8d7b70f964a52063fe32e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d28fa67ebacb1f7f37ff64f',
#        'name': 'Factory Girl',
#        'location': {'address': '193 Danforth Ave.',
#         'lat': 43.67669287762859,
#         'lng': -79.35629876225282,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67669287762859,
#           'lng': -79.35629876225282}],
#         'distance': 459,
#         'postalCode': 'M4K 1N2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['193 Danforth Ave.',
#          'Toronto ON M4K 1N2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d28fa67ebacb1f7f37ff64f-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af6e7a0f964a520060422e3',
#        'name': 'Il Fornello',
#        'location': {'address': '576 Danforth Ave.',
#         'crossStreet': 'at Carlaw Ave.',
#         'lat': 43.67860392856738,
#         'lng': -79.34690364849348,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67860392856738,
#           'lng': -79.34690364849348}],
#         'distance': 438,
#         'postalCode': 'M4K 1R1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['576 Danforth Ave. (at Carlaw Ave.)',
#          'Toronto ON M4K 1R1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af6e7a0f964a520060422e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '516c9d2de4b0cde235a2cb1a',
#        'name': 'Menchies',
#        'location': {'address': 'Danforth Ave',
#         'crossStreet': 'Pape',
#         'lat': 43.67830909198205,
#         'lng': -79.34810528402672,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67830909198205,
#           'lng': -79.34810528402672}],
#         'distance': 356,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Danforth Ave (Pape)', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-516c9d2de4b0cde235a2cb1a-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5246dbd611d23c6130e650a0',
#        'name': 'Kitchen Stuff Plus',
#        'location': {'address': '583 Danforth Ave',
#         'crossStreet': 'at Gough Ave',
#         'lat': 43.67861256318158,
#         'lng': -79.34642163596001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67861256318158,
#           'lng': -79.34642163596001}],
#         'distance': 475,
#         'postalCode': 'M4K 1P9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['583 Danforth Ave (at Gough Ave)',
#          'Toronto ON M4K 1P9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5246dbd611d23c6130e650a0-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcba1cf964a520272f21e3',
#        'name': 'Starbucks',
#        'location': {'address': '604 Danforth Avenue',
#         'crossStreet': 'at Gough Ave.',
#         'lat': 43.67872968094713,
#         'lng': -79.34618766287778,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67872968094713,
#           'lng': -79.34618766287778}],
#         'distance': 491,
#         'postalCode': 'M4K 1R1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['604 Danforth Avenue (at Gough Ave.)',
#          'Toronto ON M4K 1R1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcba1cf964a520272f21e3-40'}]}]}}

# %% [markdown]
# * Extract venue category

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# * Get venues and display first 5 using Head function

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#               name          categories        lat        lng
# 0         Pantheon    Greek Restaurant  43.677621 -79.351434
# 1     Dolce Gelato      Ice Cream Shop  43.677773 -79.351187
# 2    MenEssentials      Cosmetics Shop  43.677820 -79.351265
# 3  Cafe Fiorentina  Italian Restaurant  43.677743 -79.350115
# 4       La Diperie      Ice Cream Shop  43.677530 -79.352295

# %% [markdown]
# * Print total venues found in that area

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 41 venues were returned by Foursquare.
